# %%
########### Import into a data frame
import pandas as pd

poke_dex = pd.read_csv('Pokemon.csv')

print(poke_dex)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
import pandas as pd

poke_dex = pd.read_csv('Pokemon.csv')

print(df.head())
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
import pandas as pd

poke_dex = pd.read_csv('Pokemon.csv')

print(poke_dex.tail())
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
import pandas as pd
###############  Importing from Excel
# poke_dex = pd.read_excel('Pokemon.xlsx')

############## Importing from txt:
poke_dex = pd.read_csv('Pokemon.txt')

##### Set delimeter as needed for separation 

print(poke_dex.head(3))
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
######## Read Headers 
#print(poke_dex.columns)

######## Read each column 
#print(poke_dex.Name)
#print(poke_dex['Name'][:5])
#print(poke_dex[['Name', 'Type 1', 'HP']])

###### Read each row w/ integer location  
#print(poke_dex.iloc[3])

########## Ierate rows   
#for index, row in poke_dex.iterrows():
#    print(index, row['Name'])

########## location - .loc   -> Conditional statement
#poke_dex.loc[poke_dex['Type 1']=="Fire"]

####### Gives basic stats (count, average, min, max)
#poke_dex.describe()

########## Sorting Values
#poke_dex.sort_values('Name', ascending = True)
#poke_dex.sort_values(['Type 1', 'HP'], ascending = [1,0])

###### Read a specific location (R,C)
#print(poke_dex.iloc[2,1])
# Out:
# Venusaur

# %%
########### MAKING CHANGES TO DATA ###################

#poke_dex['Total']= poke_dex['HP']+poke_dex['Attack']+poke_dex['Defense']+poke_dex['Sp. Atk']+poke_dex['Sp. Def']+ poke_dex['Speed']
#poke_dex.head(5)

####### Drop a column
#poke_dex.drop(columns=['Total'])
#poke_dex.head(5)

##### More effecient than the top line
# The end paramater is excluded 
#poke_dex['Total']=poke_dex.iloc[:,4:10].sum(axis=1)

########### Moving columns around 
#cols = list(poke_dex.columns.values)
#poke_dex = poke_dex[cols[0:4]+[cols[-1]]+cols[4:12]]


poke_dex.head(5)
# Out:
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    318  45      49
# 1  2                Ivysaur  Grass  Poison      False    405  60      62
# 2  3               Venusaur  Grass  Poison      False    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80     100
# 4  4             Charmander   Fire     NaN      False    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  SUM  TOTAL
# 0       49       65       65     45           1  318    318
# 1       63       80       80     60           1  405    405
# 2       83      100      100     80           1  525    525
# 3      123      122      120     80           1  625    625
# 4       43       60       50     65           1  309    309

# %%
######## SAVING DATA #########
